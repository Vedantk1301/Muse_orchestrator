# %%
from qdrant_client import QdrantClient
from dotenv import load_dotenv
import os

load_dotenv()

QDRANT_URL = "https://34c56d39-9a1c-4090-9a51-45ab2ef6f6f4.us-east4-0.gcp.cloud.qdrant.io:6333"
QDRANT_API_KEY = os.getenv("QDRANT_KEY")
print(QDRANT_API_KEY)# put this in env var in real life
COLLECTION = "new_qwen_embeddings"  # or whichever you used

client = QdrantClient(url=QDRANT_URL, api_key=QDRANT_API_KEY)

# quick sanity:
print(client.get_collections())
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhY2Nlc3MiOiJtIn0.uOBiRSLZENArmjKVb8uaG5ozO8440Ib7KOtVuKSn9QE
# collections=[CollectionDescription(name='fashion_qwen4b_text'), CollectionDescription(name='mem0_fashion_qdrant'), CollectionDescription(name='mem0migrations'), CollectionDescription(name='image_embeddings'), CollectionDescription(name='mem0_memories'), CollectionDescription(name='new_qwen_embeddings')]

# %%
from qdrant_client.models import HnswConfigDiff

client.update_collection(
    collection_name=COLLECTION,
    hnsw_config=HnswConfigDiff(
        m=32,              # connections per node (16–32 is typical)
        ef_construct=256,  # high recall during index build
    )
)

print("Triggered HNSW reconfiguration for collection:", COLLECTION)
# Out:
# Triggered HNSW reconfiguration for collection: new_qwen_embeddings

# %%
info = client.get_collection(COLLECTION)

# Full dump to inspect everything
print(info)

# Just HNSW config
print("HNSW config:", info.config.hnsw_config)

# Or pretty-print as dict
print("HNSW config dict:", info.config.hnsw_config.dict())
# Out:
# status=<CollectionStatus.YELLOW: 'yellow'> optimizer_status=<OptimizersStatusOneOf.OK: 'ok'> warnings=None indexed_vectors_count=67584 points_count=68135 segments_count=4 config=CollectionConfig(params=CollectionParams(vectors=VectorParams(size=2560, distance=<Distance.COSINE: 'Cosine'>, hnsw_config=None, quantization_config=None, on_disk=None, datatype=None, multivector_config=None), shard_number=1, sharding_method=None, replication_factor=1, write_consistency_factor=1, read_fan_out_factor=None, on_disk_payload=True, sparse_vectors=None), hnsw_config=HnswConfig(m=32, ef_construct=256, full_scan_threshold=10000, max_indexing_threads=0, on_disk=False, payload_m=None, inline_storage=None), optimizer_config=OptimizersConfig(deleted_threshold=0.2, vacuum_min_vector_number=1000, default_segment_number=0, max_segment_size=None, memmap_threshold=None, indexing_threshold=10000, flush_interval_sec=5, max_optimization_threads=None), wal_config=WalConfig(wal_capacity_mb=32, wal_segments_ahead=0
# ...
